# %% [markdown]
# # Artificial Neural Networks and Deep Learning
#
# ---
#
# ## Homework 2: Minimal Working Example
#
# To make your first submission, follow these steps:
# 1. Create a folder named `[2024-2025] AN2DL/Homework 2` in your Google Drive.
# 2. Upload the `mars_for_students.npz` file to this folder.
# 3. Upload the Jupyter notebook `Homework 2 - Minimal Working Example.ipynb`.
# 4. Load and process the data.
# 5. Implement and train your model.
# 6. Submit the generated `.csv` file to Kaggle.

# %% [markdown]
# ## 🌐 Connect Colab to Google Drive

# %%
from google.colab import drive

drive.mount("/gdrive")
# %cd /gdrive/MyDrive/Polimi/ANNDL/challenge2
# Out:
# Mounted at /gdrive
# /gdrive/MyDrive/Polimi/ANNDL/challenge2

# %% [markdown]
# ## ⚙️ Import Libraries

# %%
# Set seed for reproducibility
seed = 42

# Import necessary libraries
import os

# Set environment variables before importing modules
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np

# Set seeds for random number generators in NumPy and Python
np.random.seed(seed)
random.seed(seed)

# Import TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator


# Set seed for TensorFlow
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# Reduce TensorFlow verbosity
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# Print TensorFlow version
print(tf.__version__)

# Import other libraries
import os
import math
from PIL import Image
from keras import backend as K
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.colors as mcolors

from datetime import datetime
import pandas as pd

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline
# Out:
# 2.17.1

# %% [markdown]
# ## ⏳ Load the Data

# %%
data = np.load("mars_for_students.npz")

training_set = data["training_set"]
X_train = training_set[:, 0]
y_train = training_set[:, 1]

X_test = data["test_set"]

# Separiamo il train set in training e validation set
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.2, random_state=42  # 20% per il validation set
)

# Add color channel and rescale pixels between 0 and 1
X_train = X_train[..., np.newaxis] / 255.0
###
X_val = X_val[..., np.newaxis] / 255.0
X_test = X_test[..., np.newaxis] / 255.0

y_train = y_train.astype(np.int32)
y_val = y_val.astype(np.int32)

print(f"Training X shape: {X_train.shape}")
print(f"Validation X shape: {X_val.shape}")
print(f"Training y shape: {y_train.shape}")
print(f"Test X shape: {X_test.shape}")
# Out:
# Training X shape: (2092, 64, 128, 1)
# Validation X shape: (523, 64, 128, 1)
# Training y shape: (2092, 64, 128)
# Test X shape: (10022, 64, 128, 1)

# %%
category_map = {
  0: 0, #Background
  1: 1, #Soil
  2: 2, #Bedrock
  3: 3, #Sand
  4: 4, #Big Rock
}

# %%
def visualize_image_label_pairs(X, y, num_images, class_names, reverse=0):
    """
    Visualize pairs of original images and their corresponding label overlays,
    and add a color legend for the labels.

    Args:
        X: Array of images (shape: [num_samples, height, width, channels]).
        y: Array of labels (shape: [num_samples, height, width]).
        num_images: Number of image-label pairs to visualize.
        class_names: List of class names (optional). If provided, a legend will be added.
    """

    if reverse == 1:
        X = X[::-1]
        y = y[::-1]

    # Set up the grid layout: 2 columns, num_images rows
    fig, axes = plt.subplots(num_images, 2, figsize=(10, 5 * num_images))

    # Define a custom colormap for the legend
    if class_names is not None:
        cmap = mcolors.ListedColormap(plt.cm.jet(np.linspace(0, 1, len(class_names))))
        norm = mcolors.BoundaryNorm(np.arange(len(class_names)+1), len(class_names))
    else:
        cmap = 'jet'
        norm = None

    for i in range(num_images):
        # Extract the image and its corresponding label
        image = X[i]
        label = y[i]

        # Show the original image in the first column
        ax = axes[i, 0] if num_images > 1 else axes[0]
        ax.imshow(image.squeeze(), cmap='gray')  # Use squeeze for grayscale images
        ax.axis('off')
        ax.set_title(f"Image {i+1}")

        # Show the image with the label overlay in the second column
        ax = axes[i, 1] if num_images > 1 else axes[1]
        ax.imshow(image.squeeze(), cmap='gray')  # Background: original image
        ax.imshow(label, alpha=0.5, cmap=cmap, norm=norm)  # Label overlay
        ax.axis('off')
        ax.set_title(f"Label Overlay {i+1}")

    # Add the legend if class names are provided
    if class_names is not None:
        handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=cmap(i), markersize=10) for i in range(len(class_names))]
        plt.legend(handles, class_names, title="Class Labels", bbox_to_anchor=(1.05, 1), loc='upper left')

    plt.tight_layout()
    plt.show()

# %%
visualize_image_label_pairs(X_train, y_train, num_images=10, class_names=category_map, reverse=1)

# %% [markdown]
# ##Apply augmentation

# %%
# Function to apply data augmentation
def augment_data(X, y, augmenter, num_augmentations=1):
    """
    Perform data augmentation on the dataset and return augmented images and labels.

    Parameters:
    - X: array of images of shape (num_samples, height, width, channels)
    - y: array of labels (segmentation masks) of shape (num_samples, height, width)
    - augmenter: an image augmentation generator (e.g., from Keras)
    - num_augmentations: number of augmentations to generate for each image

    Returns:
    - augmented_X: augmented images
    - augmented_y: corresponding labels (must remain integer labels)
    """
    augmented_X, augmented_y = [], []

    for i in range(len(X)):
        img = X[i].reshape((1,) + X[i].shape)  # Expand to 4 dimensions
        label = y[i]

        # Ensure that labels are integers (just in case)
        label = label.astype(int)

        for _ in range(num_augmentations):
            for augmented_img in augmenter.flow(img, batch_size=1):
                augmented_X.append(augmented_img[0])  # Add augmented image
                augmented_y.append(label)  # Add corresponding label (unchanged)
                break  # Exit to avoid duplicates

    return np.array(augmented_X), np.array(augmented_y)

# %%
# Define data augmentation parameters
augmenter = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True
)

# Apply data augmentation to the training set
augmented_X, augmented_y = augment_data(X_train, y_train, augmenter, num_augmentations=2)

# Concatenate original data with augmented data
X_train_augmented = np.concatenate((X_train, augmented_X), axis=0)
y_train_augmented = np.concatenate((y_train, augmented_y), axis=0)

# Print dataset shapes
print(f"Original training set size: {X_train.shape}")
print(f"Augmented training set size: {X_train_augmented.shape}")
print(f"Original labels size: {y_train.shape}")
print(f"Augmented labels size: {y_train_augmented.shape}")

X_train = X_train_augmented
y_train = y_train_augmented
# Out:
# Original training set size: (2092, 64, 128, 1)
# Augmented training set size: (6276, 64, 128, 1)
# Original labels size: (2092, 64, 128)
# Augmented labels size: (6276, 64, 128)

# %%
def create_segmentation_colormap(num_classes):
    """
    Create a linear colormap using a predefined palette.
    Uses 'viridis' as default because it is perceptually uniform
    and works well for colorblindness.
    """
    return plt.cm.viridis(np.linspace(0, 1, num_classes))

def apply_colormap(label, colormap=None):
    """
    Apply the colormap to a label.
    """
    # Ensure label is 2D
    label = np.squeeze(label)

    if colormap is None:
        num_classes = len(np.unique(label))
        colormap = create_segmentation_colormap(num_classes)

    # Apply the colormap
    colored = colormap[label.astype(int)]

    return colored

def plot_sample_batch(x, y, num_samples=3, class_names=None):
    """
    Display some image and label pairs with label overlays.
    Parameters:
    - x: Array of images.
    - y: Array of labels.
    - num_samples: Number of samples to display.
    - class_names: List of class names for the legend.
    """
    plt.figure(figsize=(15, 5 * num_samples))

    num_classes = len(np.unique(y))
    colormap = create_segmentation_colormap(num_classes)

    for j in range(min(num_samples, len(x))):
        # Plot original image
        plt.subplot(num_samples, 2, j * 2 + 1)
        plt.imshow(x[j].squeeze(), cmap='gray')  # Display grayscale image
        plt.title(f'Image {j+1}')
        plt.axis('off')

        # Plot image with label overlay
        plt.subplot(num_samples, 2, j * 2 + 2)
        plt.imshow(x[j].squeeze(), cmap='gray')  # Display grayscale image as background
        colored_label = apply_colormap(y[j], colormap)
        plt.imshow(colored_label, alpha=0.5)  # Overlay label with transparency
        plt.title(f'Label Overlay {j+1}')
        plt.axis('off')

    # Add legend if class names are provided
    if class_names is not None:
        handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=colormap[i], markersize=10)
                   for i in range(len(class_names))]
        plt.legend(handles, class_names, title="Class Labels", bbox_to_anchor=(1.05, 1), loc='upper left')

    plt.tight_layout()
    plt.show()
    plt.close()

# Example usage
print("Visualizing examples from the training set:")
plot_sample_batch(X_train, y_train, num_samples=10)
# Out:
# Visualizing examples from the training set:

# %% [markdown]
# ##Build model

# %%
num_classes = len(np.unique(y_train))
input_shape = (64, 128, 1)

# %%
# Definizione del blocco dell'encoder
def encoder_block(input_tensor, num_filters):
    # Primo layer convoluzionale
    x = tfkl.Conv2D(num_filters, (3, 3), padding='same')(input_tensor)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.LeakyReLU(negative_slope=0.1)(x)
    x = tfkl.Dropout(0.3)(x)

    # Secondo layer convoluzionale
    x = tfkl.Conv2D(num_filters, (3, 3), padding='same')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.LeakyReLU(negative_slope=0.1)(x)
    x = tfkl.Dropout(0.3)(x)

    # MaxPooling per downsampling
    p = tfkl.MaxPooling2D((2, 2))(x)
    return x, p

# Definizione del blocco del decoder
def decoder_block(input_tensor, concat_tensor, num_filters):
    # Upsampling (upscaling) della feature map
    x = tfkl.Conv2DTranspose(num_filters, (3, 3), strides=(2, 2), padding='same')(input_tensor)

    # Concatenazione con l'output dell'encoder corrispondente
    x = tfkl.concatenate([x, concat_tensor])

    # Convoluzione dopo la concatenazione
    x = tfkl.Conv2D(num_filters, (3, 3), padding='same')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.LeakyReLU(negative_slope=0.1)(x)
    x = tfkl.Dropout(0.3)(x)

    x = tfkl.Conv2D(num_filters, (3, 3), padding='same')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.LeakyReLU(negative_slope=0.1)(x)
    x = tfkl.Dropout(0.3)(x)

    return x

def build_dual_unet(input_shape, num_filters=64, num_classes=5):
    inputs = tfkl.Input(shape=input_shape)

    # Encoder per la parte dettagliata (conserviamo risoluzione più alta)
    encoder1, pool1 = encoder_block(inputs, num_filters)
    encoder2, pool2 = encoder_block(pool1, num_filters * 2)
    encoder3, pool3 = encoder_block(pool2, num_filters * 4)

    # Decoder per la parte dettagliata
    decoder1 = decoder_block(encoder3, encoder2, num_filters * 2)
    decoder2 = decoder_block(decoder1, encoder1, num_filters)

    # Encoder per la parte globale (riduzione risoluzione più rapida)
    encoder_g1, pool_g1 = encoder_block(inputs, num_filters)
    encoder_g2, pool_g2 = encoder_block(pool_g1, num_filters * 2)

    # Decoder per la parte globale
    decoder_g1 = decoder_block(encoder_g2, encoder_g1, num_filters)

    # Fusione dei due rami (dettagliato e globale)
    merged = tfkl.concatenate([decoder2, decoder_g1])

    # Output finale: 5 canali per le 5 classi, usando softmax per probabilità
    output = tfkl.Conv2D(num_classes, (1, 1), activation='softmax')(merged)

    model = tf.keras.Model(inputs=inputs, outputs=output)

    return model

model = build_dual_unet(input_shape)

# %%
model.summary()
# Visualize the model and save the image
tfk.utils.plot_model(model, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 64, 128, 1)     │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 64, 128, 64)    │            640 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 64, 128, 64)    │            256 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu (LeakyReLU)   │ (None, 64, 128, 64)    │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 64, 128, 64)    │              0 │ leaky_re_lu[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 64, 128, 64)    │         36,928 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 64, 128, 64)    │            256 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_1 (LeakyReLU) │ (None, 64, 128, 64)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 64, 128, 64)    │              0 │ leaky_re_lu_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 32, 64, 64)     │              0 │ dropout_1[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 32, 64, 128)    │         73,856 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 32, 64, 128)    │            512 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_2 (LeakyReLU) │ (None, 32, 64, 128)    │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 32, 64, 128)    │              0 │ leaky_re_lu_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 32, 64, 128)    │        147,584 │ dropout_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 32, 64, 128)    │            512 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_3 (LeakyReLU) │ (None, 32, 64, 128)    │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 32, 64, 128)    │              0 │ leaky_re_lu_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 16, 32, 128)    │              0 │ dropout_3[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 16, 32, 256)    │        295,168 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 16, 32, 256)    │          1,024 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 64, 128, 64)    │            640 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_4 (LeakyReLU) │ (None, 16, 32, 256)    │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 64, 128, 64)    │            256 │ conv2d_10[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_4 (Dropout)       │ (None, 16, 32, 256)    │              0 │ leaky_re_lu_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_10            │ (None, 64, 128, 64)    │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 16, 32, 256)    │        590,080 │ dropout_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_10 (Dropout)      │ (None, 64, 128, 64)    │              0 │ leaky_re_lu_10[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 16, 32, 256)    │          1,024 │ conv2d_5[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 64, 128, 64)    │         36,928 │ dropout_10[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_5 (LeakyReLU) │ (None, 16, 32, 256)    │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 64, 128, 64)    │            256 │ conv2d_11[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_5 (Dropout)       │ (None, 16, 32, 256)    │              0 │ leaky_re_lu_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_11            │ (None, 64, 128, 64)    │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 32, 64, 128)    │        295,040 │ dropout_5[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_11 (Dropout)      │ (None, 64, 128, 64)    │              0 │ leaky_re_lu_11[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 32, 64, 256)    │              0 │ conv2d_transpose[0][0… │
# │                           │                        │                │ dropout_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 32, 64, 64)     │              0 │ dropout_11[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 32, 64, 128)    │        295,040 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 32, 64, 128)    │         73,856 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 32, 64, 128)    │            512 │ conv2d_6[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 32, 64, 128)    │            512 │ conv2d_12[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_6 (LeakyReLU) │ (None, 32, 64, 128)    │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_12            │ (None, 32, 64, 128)    │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_6 (Dropout)       │ (None, 32, 64, 128)    │              0 │ leaky_re_lu_6[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_12 (Dropout)      │ (None, 32, 64, 128)    │              0 │ leaky_re_lu_12[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 32, 64, 128)    │        147,584 │ dropout_6[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 32, 64, 128)    │        147,584 │ dropout_12[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 32, 64, 128)    │            512 │ conv2d_7[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 32, 64, 128)    │            512 │ conv2d_13[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_7 (LeakyReLU) │ (None, 32, 64, 128)    │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_13            │ (None, 32, 64, 128)    │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_7 (Dropout)       │ (None, 32, 64, 128)    │              0 │ leaky_re_lu_7[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_13 (Dropout)      │ (None, 32, 64, 128)    │              0 │ leaky_re_lu_13[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 64, 128, 64)    │         73,792 │ dropout_7[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 64, 128, 64)    │         73,792 │ dropout_13[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 64, 128, 128)   │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 64, 128, 128)   │              0 │ conv2d_transpose_2[0]… │
# │ (Concatenate)             │                        │                │ dropout_11[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 64, 128, 64)    │         73,792 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 64, 128, 64)    │         73,792 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 64, 128, 64)    │            256 │ conv2d_8[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_14    │ (None, 64, 128, 64)    │            256 │ conv2d_14[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_8 (LeakyReLU) │ (None, 64, 128, 64)    │              0 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_14            │ (None, 64, 128, 64)    │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_8 (Dropout)       │ (None, 64, 128, 64)    │              0 │ leaky_re_lu_8[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_14 (Dropout)      │ (None, 64, 128, 64)    │              0 │ leaky_re_lu_14[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 64, 128, 64)    │         36,928 │ dropout_8[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 64, 128, 64)    │         36,928 │ dropout_14[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 64, 128, 64)    │            256 │ conv2d_9[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_15    │ (None, 64, 128, 64)    │            256 │ conv2d_15[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_9 (LeakyReLU) │ (None, 64, 128, 64)    │              0 │ batch_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_15            │ (None, 64, 128, 64)    │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_9 (Dropout)       │ (None, 64, 128, 64)    │              0 │ leaky_re_lu_9[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_15 (Dropout)      │ (None, 64, 128, 64)    │              0 │ leaky_re_lu_15[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 64, 128, 128)   │              0 │ dropout_9[0][0],       │
# │ (Concatenate)             │                        │                │ dropout_15[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 64, 128, 5)     │            645 │ concatenate_3[0][0]    │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 2,517,765 (9.60 MB)
#  Trainable params: 2,514,181 (9.59 MB)
#  Non-trainable params: 3,584 (14.00 KB)

# %% [markdown]
# ## 🛠️ Train and Save the Model

# %%
def masked_loss(y_true, y_pred):
    # Create a mask to exclude pixels with label 0
    mask = tf.cast(tf.not_equal(y_true, 0), tf.float32)

    # Compute standard loss (sparse categorical crossentropy)
    loss = tf.keras.losses.sparse_categorical_crossentropy(y_true, y_pred)

    # Apply the mask (exclude pixels with label 0)
    loss = loss * mask

    # Return the mean loss over all pixels
    return tf.reduce_sum(loss) / tf.reduce_sum(mask)

# %%
# Define the MeanIoU ignoring the background class
mean_iou = tfk.metrics.MeanIoU(num_classes=num_classes, ignore_class=0, sparse_y_pred=False)

model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=[mean_iou])

# %%
# Early stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=10,          # Stop after 10 epochs without improvement
    restore_best_weights=True  # Restore model weights from the best epoch
)

# Learning rate scheduler (ReduceLR on Plateau)
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',   # Monitor validation loss
    factor=0.5,           # Reduce learning rate by 50%
    patience=3,           # Wait for 3 epochs before reducing LR
    min_lr=1e-6           # Minimum learning rate
)

# %%
# Train the model with early stopping and learning rate scheduler
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    batch_size=32,
    epochs=100
)
# Out:
# Epoch 1/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 58s 128ms/step - loss: 1.4980 - mean_io_u: 0.1351 - val_loss: 2.4510 - val_mean_io_u: 0.0550
# Epoch 2/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 1.2413 - mean_io_u: 0.2105 - val_loss: 1.3441 - val_mean_io_u: 0.1921
# Epoch 3/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 1.1152 - mean_io_u: 0.2678 - val_loss: 1.3359 - val_mean_io_u: 0.2417
# Epoch 4/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 1.0670 - mean_io_u: 0.2873 - val_loss: 1.5797 - val_mean_io_u: 0.1812
# Epoch 5/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 1.0274 - mean_io_u: 0.3071 - val_loss: 0.9951 - val_mean_io_u: 0.3345
# Epoch 6/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 1.0127 - mean_io_u: 0.3132 - val_loss: 0.9937 - val_mean_io_u: 0.3528
# Epoch 7/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.9898 - mean_io_u: 0.3259 - val_loss: 0.9420 - val_mean_io_u: 0.3642
# Epoch 8/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.9782 - mean_io_u: 0.3305 - val_loss: 0.9072 - val_mean_io_u: 0.3692
# Epoch 9/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.9668 - mean_io_u: 0.3358 - val_loss: 0.9452 - val_mean_io_u: 0.3438
# Epoch 10/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.9568 - mean_io_u: 0.3389 - val_loss: 0.9475 - val_mean_io_u: 0.3447
# Epoch 11/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.9465 - mean_io_u: 0.3425 - val_loss: 0.9467 - val_mean_io_u: 0.3578
# Epoch 12/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.9404 - mean_io_u: 0.3445 - val_loss: 0.9056 - val_mean_io_u: 0.3604
# Epoch 13/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.9262 - mean_io_u: 0.3506 - val_loss: 0.9280 - val_mean_io_u: 0.3581
# Epoch 14/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.9187 - mean_io_u: 0.3542 - val_loss: 1.0475 - val_mean_io_u: 0.2986
# Epoch 15/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.9065 - mean_io_u: 0.3591 - val_loss: 0.9176 - val_mean_io_u: 0.3671
# Epoch 16/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.8934 - mean_io_u: 0.3642 - val_loss: 0.8923 - val_mean_io_u: 0.3762
# Epoch 17/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.8841 - mean_io_u: 0.3674 - val_loss: 0.8587 - val_mean_io_u: 0.4052
# Epoch 18/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.8762 - mean_io_u: 0.3717 - val_loss: 0.8875 - val_mean_io_u: 0.3892
# Epoch 19/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.8683 - mean_io_u: 0.3745 - val_loss: 0.9016 - val_mean_io_u: 0.3905
# Epoch 20/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.8591 - mean_io_u: 0.3788 - val_loss: 0.9086 - val_mean_io_u: 0.3923
# Epoch 21/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.8548 - mean_io_u: 0.3797 - val_loss: 0.9030 - val_mean_io_u: 0.3990
# Epoch 22/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.8460 - mean_io_u: 0.3829 - val_loss: 0.8323 - val_mean_io_u: 0.4139
# Epoch 23/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.8407 - mean_io_u: 0.3849 - val_loss: 0.8604 - val_mean_io_u: 0.4120
# Epoch 24/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.8371 - mean_io_u: 0.3853 - val_loss: 0.8698 - val_mean_io_u: 0.4056
# Epoch 25/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.8282 - mean_io_u: 0.3895 - val_loss: 0.8908 - val_mean_io_u: 0.3961
# Epoch 26/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.8268 - mean_io_u: 0.3892 - val_loss: 0.8144 - val_mean_io_u: 0.4252
# Epoch 27/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.8250 - mean_io_u: 0.3902 - val_loss: 0.8210 - val_mean_io_u: 0.4210
# Epoch 28/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.8120 - mean_io_u: 0.3949 - val_loss: 0.9032 - val_mean_io_u: 0.3760
# Epoch 29/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.8125 - mean_io_u: 0.3946 - val_loss: 0.8803 - val_mean_io_u: 0.3895
# Epoch 30/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.8063 - mean_io_u: 0.3976 - val_loss: 0.8697 - val_mean_io_u: 0.4035
# Epoch 31/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.8022 - mean_io_u: 0.3982 - val_loss: 0.8676 - val_mean_io_u: 0.4056
# Epoch 32/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.7981 - mean_io_u: 0.4000 - val_loss: 0.9071 - val_mean_io_u: 0.3829
# Epoch 33/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.7916 - mean_io_u: 0.4009 - val_loss: 0.8634 - val_mean_io_u: 0.3951
# Epoch 34/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.7886 - mean_io_u: 0.4035 - val_loss: 0.9824 - val_mean_io_u: 0.3461
# Epoch 35/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.7816 - mean_io_u: 0.4057 - val_loss: 0.8760 - val_mean_io_u: 0.3922
# Epoch 36/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.7786 - mean_io_u: 0.4058 - val_loss: 0.8425 - val_mean_io_u: 0.4162
# Epoch 37/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.7747 - mean_io_u: 0.4067 - val_loss: 0.8564 - val_mean_io_u: 0.4008
# Epoch 38/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.7636 - mean_io_u: 0.4122 - val_loss: 0.8413 - val_mean_io_u: 0.4100
# Epoch 39/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.7646 - mean_io_u: 0.4104 - val_loss: 0.8442 - val_mean_io_u: 0.4022
# Epoch 40/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.7557 - mean_io_u: 0.4144 - val_loss: 0.8479 - val_mean_io_u: 0.4048
# Epoch 41/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.7566 - mean_io_u: 0.4146 - val_loss: 0.8872 - val_mean_io_u: 0.3828
# Epoch 42/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.7490 - mean_io_u: 0.4166 - val_loss: 0.8418 - val_mean_io_u: 0.3999
# Epoch 43/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.7403 - mean_io_u: 0.4196 - val_loss: 0.8793 - val_mean_io_u: 0.3839
# Epoch 44/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.7376 - mean_io_u: 0.4210 - val_loss: 0.8431 - val_mean_io_u: 0.4120
# Epoch 45/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.7370 - mean_io_u: 0.4215 - val_loss: 0.8346 - val_mean_io_u: 0.4056
# Epoch 46/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.7323 - mean_io_u: 0.4227 - val_loss: 0.8436 - val_mean_io_u: 0.3955
# Epoch 47/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.7291 - mean_io_u: 0.4237 - val_loss: 0.8399 - val_mean_io_u: 0.3961
# Epoch 48/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.7234 - mean_io_u: 0.4262 - val_loss: 0.8475 - val_mean_io_u: 0.3882
# Epoch 49/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.7232 - mean_io_u: 0.4266 - val_loss: 0.8241 - val_mean_io_u: 0.4010
# Epoch 50/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.7204 - mean_io_u: 0.4270 - val_loss: 0.8285 - val_mean_io_u: 0.4075
# Epoch 51/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.7158 - mean_io_u: 0.4290 - val_loss: 0.7813 - val_mean_io_u: 0.4305
# Epoch 52/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.7119 - mean_io_u: 0.4293 - val_loss: 0.8160 - val_mean_io_u: 0.4145
# Epoch 53/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.7066 - mean_io_u: 0.4307 - val_loss: 0.8115 - val_mean_io_u: 0.4174
# Epoch 54/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.7002 - mean_io_u: 0.4332 - val_loss: 0.8773 - val_mean_io_u: 0.3802
# Epoch 55/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.7011 - mean_io_u: 0.4323 - val_loss: 1.0059 - val_mean_io_u: 0.3128
# Epoch 56/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.6942 - mean_io_u: 0.4350 - val_loss: 1.1101 - val_mean_io_u: 0.2787
# Epoch 57/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.6950 - mean_io_u: 0.4343 - val_loss: 0.9949 - val_mean_io_u: 0.3206
# Epoch 58/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.6951 - mean_io_u: 0.4343 - val_loss: 1.0107 - val_mean_io_u: 0.3334
# Epoch 59/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.6900 - mean_io_u: 0.4365 - val_loss: 1.0002 - val_mean_io_u: 0.3311
# Epoch 60/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.6857 - mean_io_u: 0.4383 - val_loss: 1.0492 - val_mean_io_u: 0.3071
# Epoch 61/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.6851 - mean_io_u: 0.4381 - val_loss: 1.1909 - val_mean_io_u: 0.2716
# Epoch 62/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.6752 - mean_io_u: 0.4417 - val_loss: 1.2108 - val_mean_io_u: 0.2600
# Epoch 63/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.6753 - mean_io_u: 0.4420 - val_loss: 1.2641 - val_mean_io_u: 0.2512
# Epoch 64/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.6729 - mean_io_u: 0.4427 - val_loss: 1.1598 - val_mean_io_u: 0.2879
# Epoch 65/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.6718 - mean_io_u: 0.4428 - val_loss: 1.1069 - val_mean_io_u: 0.2985
# Epoch 66/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.6631 - mean_io_u: 0.4473 - val_loss: 1.1792 - val_mean_io_u: 0.2963
# Epoch 67/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.6578 - mean_io_u: 0.4482 - val_loss: 1.1782 - val_mean_io_u: 0.2786
# Epoch 68/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.6563 - mean_io_u: 0.4499 - val_loss: 1.1525 - val_mean_io_u: 0.2884
# Epoch 69/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.6527 - mean_io_u: 0.4504 - val_loss: 1.2876 - val_mean_io_u: 0.2741
# Epoch 70/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.6486 - mean_io_u: 0.4512 - val_loss: 1.3801 - val_mean_io_u: 0.2695
# Epoch 71/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.6434 - mean_io_u: 0.4520 - val_loss: 1.0645 - val_mean_io_u: 0.3529
# Epoch 72/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.6470 - mean_io_u: 0.4516 - val_loss: 0.9473 - val_mean_io_u: 0.3871
# Epoch 73/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.6405 - mean_io_u: 0.4550 - val_loss: 0.9911 - val_mean_io_u: 0.3789
# Epoch 74/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.6417 - mean_io_u: 0.4553 - val_loss: 1.0052 - val_mean_io_u: 0.3893
# Epoch 75/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.6412 - mean_io_u: 0.4534 - val_loss: 0.9845 - val_mean_io_u: 0.3922
# Epoch 76/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.6356 - mean_io_u: 0.4563 - val_loss: 0.9673 - val_mean_io_u: 0.3996
# Epoch 77/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.6280 - mean_io_u: 0.4598 - val_loss: 0.9910 - val_mean_io_u: 0.3946
# Epoch 78/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.6251 - mean_io_u: 0.4597 - val_loss: 1.0030 - val_mean_io_u: 0.3991
# Epoch 79/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.6225 - mean_io_u: 0.4600 - val_loss: 0.9470 - val_mean_io_u: 0.4111
# Epoch 80/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.6187 - mean_io_u: 0.4616 - val_loss: 1.0013 - val_mean_io_u: 0.3939
# Epoch 81/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.6235 - mean_io_u: 0.4593 - val_loss: 0.9181 - val_mean_io_u: 0.4045
# Epoch 82/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.6192 - mean_io_u: 0.4612 - val_loss: 0.8758 - val_mean_io_u: 0.4222
# Epoch 83/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.6109 - mean_io_u: 0.4653 - val_loss: 1.0312 - val_mean_io_u: 0.3929
# Epoch 84/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.6091 - mean_io_u: 0.4659 - val_loss: 0.9511 - val_mean_io_u: 0.4089
# Epoch 85/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.6082 - mean_io_u: 0.4646 - val_loss: 0.9440 - val_mean_io_u: 0.4008
# Epoch 86/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.6017 - mean_io_u: 0.4668 - val_loss: 1.0011 - val_mean_io_u: 0.3959
# Epoch 87/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.5989 - mean_io_u: 0.4681 - val_loss: 0.9219 - val_mean_io_u: 0.4053
# Epoch 88/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.5975 - mean_io_u: 0.4689 - val_loss: 0.9281 - val_mean_io_u: 0.4015
# Epoch 89/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.5910 - mean_io_u: 0.4694 - val_loss: 0.9422 - val_mean_io_u: 0.3987
# Epoch 90/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.5905 - mean_io_u: 0.4701 - val_loss: 0.9108 - val_mean_io_u: 0.4080
# Epoch 91/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.5824 - mean_io_u: 0.4720 - val_loss: 0.9783 - val_mean_io_u: 0.3920
# Epoch 92/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.5833 - mean_io_u: 0.4721 - val_loss: 0.9386 - val_mean_io_u: 0.4081
# Epoch 93/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.5782 - mean_io_u: 0.4735 - val_loss: 1.0686 - val_mean_io_u: 0.3762
# Epoch 94/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.5855 - mean_io_u: 0.4706 - val_loss: 1.2593 - val_mean_io_u: 0.3575
# Epoch 95/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.5747 - mean_io_u: 0.4742 - val_loss: 1.1600 - val_mean_io_u: 0.3760
# Epoch 96/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.5773 - mean_io_u: 0.4729 - val_loss: 1.5304 - val_mean_io_u: 0.3115
# Epoch 97/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.5760 - mean_io_u: 0.4744 - val_loss: 1.2279 - val_mean_io_u: 0.3537
# Epoch 98/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.5732 - mean_io_u: 0.4732 - val_loss: 1.1772 - val_mean_io_u: 0.3861
# Epoch 99/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.5681 - mean_io_u: 0.4760 - val_loss: 1.2035 - val_mean_io_u: 0.3843
# Epoch 100/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.5653 - mean_io_u: 0.4774 - val_loss: 1.1725 - val_mean_io_u: 0.3886

# %%
# Save the trained model to a file with the accuracy included in the filename
model_filename = 'model4.keras'
model.save(model_filename)

# %% [markdown]
# ##Results

# %%
# Make predictions on the validation set
predictions = model.predict(X_val)
predicted_classes = np.argmax(predictions, axis=-1)

# Function to visualize predictions
def visualize_predictions(X, y_true, y_pred, num_examples=5):
    """
    Visualize predictions vs true labels for the validation set.
    Args:
        X: Input images (validation set).
        y_true: True labels.
        y_pred: Predicted labels.
        num_examples: Number of examples to visualize.
    """
    plt.figure(figsize=(15, num_examples * 5))

    for i in range(num_examples):
        # Input image
        plt.subplot(num_examples, 3, i * 3 + 1)
        plt.imshow(X[i, :, :, 0], cmap='gray')  # Show the grayscale input
        plt.title("Input Image")
        plt.axis('off')

        # True label
        plt.subplot(num_examples, 3, i * 3 + 2)
        plt.imshow(y_true[i], cmap='tab10')  # Show true labels
        plt.title("True Label")
        plt.axis('off')

        # Predicted label
        plt.subplot(num_examples, 3, i * 3 + 3)
        plt.imshow(y_pred[i], cmap='tab10')  # Show predicted labels
        plt.title("Predicted Label")
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# Visualize predictions on the first few examples
visualize_predictions(X_val, y_val, predicted_classes, num_examples=5)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step

# %% [markdown]
# ## 📊 Prepare Your Submission
#
# In our Kaggle competition, submissions are made as `csv` files. To create a proper `csv` file, you need to flatten your predictions and include an `id` column as the first column of your dataframe. To maintain consistency between your results and our solution, please avoid shuffling the test set. The code below demonstrates how to prepare the `csv` file from your model predictions.

# %%
model = tfk.models.load_model('model4.keras', compile=False)
print(f"Model loaded from {model_filename}")
# Out:
# Model loaded from model4.keras

# %%
preds = model.predict(X_test)
preds = np.argmax(preds, axis=-1)
print(f"Predictions shape: {preds.shape}")
# Out:
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step
# Predictions shape: (10022, 64, 128)

# %%
def y_to_df(y) -> pd.DataFrame:
    """Converts segmentation predictions into a DataFrame format for Kaggle."""
    n_samples = len(y)
    y_flat = y.reshape(n_samples, -1)
    df = pd.DataFrame(y_flat)
    df["id"] = np.arange(n_samples)
    cols = ["id"] + [col for col in df.columns if col != "id"]
    return df[cols]

# %%
# Create and download the csv submission file
timestep_str = model_filename.replace("model_", "").replace(".keras", "")
submission_filename = f"submission_{timestep_str}.csv"
submission_df = y_to_df(preds)
submission_df.to_csv(submission_filename, index=False)

from google.colab import files
files.download(submission_filename)
